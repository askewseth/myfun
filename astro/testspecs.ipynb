# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 7)
import myfun as m
import myfun.astro as ast
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %%
s = ast.rspec(filt='psi')
print s.obj_name
# Out:
# epsilon psa

# %%
s.plot()

# %%
data = s.fulldata

# %%
ast.normalize_data(*data)

# %%
ast.normalize_spec(*data, tol=1)
# Out:
# R^2 Values:
# 	Linear: 0.999999457809
# 	Quadratic: 0.999959133544

# %%
specs = ast.rspecs(num=20)

# %%
ast.filter_tolerance_list(*specs[4].fulldata)

# %%
ast.normalize_spec(*specs[4].fulldata, tol=1)

# %%
pss, fll = ast.filter_tolerance(*specs[4].fulldata)

# %%
for i, s in enumerate(specs):
    print i
    s.plot()

# %%
plt.plot(pss[0],pss[1])

# %%
t = [True, False]

# %%
any(t)

# %%
ast.filter_tolerance_list(*specs[4].fulldata)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-da8e0754d299> in <module>()
# ----> 1 ast.filter_tolerance_list(*specs[4].fulldata)
#
# /home/oort/myfun/astro/stats.py in filter_tolerance_list(wls, data, tol, pas, filtfrom)
#      28     # assert None not in filtfrom
#      29     filt1plot = filter(lambda x: abs(filtfrom-x[0][1]) < tol * sigma,
# ---> 30                        zip(plotdata, filtfrom)
#      31                        )
#      32     filt1plotnot = filter(lambda x: abs(filtfrom-x[0][1]) > tol * sigma,
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
ast.normalize_spec(*specs[2].fulldata)
# Out:
# R^2 Values:
# 	Linear: 0.999999188452
# 	Quadratic: 0.998152730616
# assuming linear fit better
# R^2 Values:
# 	Linear: 0.999999455903
# 	Quadratic: 0.999768099865
# normal length 2124

# %%
ast.filter_tolerance(*specs[4].fulldata)
# Out:
# ([[6510.05173534307,
#    6510.09930089907,
#    6510.146866455069,
#    6510.19443201107,
#    6510.24199756707,
#    6510.2895631230695,
#    6510.33712867907,
#    6510.384694235069,
#    6510.43225979107,
#    6510.47982534707,
#    6510.527390903069,
#    6510.57495645907,
#    6510.62252201507,
#    6510.670087571069,
#    6510.71765312707,
#    6510.765218683069,
#    6510.8127842390695,
#    6510.86034979507,
#    6510.907915351069,
#    6510.95548090707,
#    6511.00304646307,
#    6511.050612019069,
#    6511.09817757507,
#    6511.14574313107,
#    6511.1933086870695,
#    6511.24087424307,
#    6511.288439799069,
#    6511.33600535507,
#    6511.38357091107,
#    6511.431136467069,
#    6511.47870202307,
#    6511.52626757907,
#    6511.573833135069,
#    6511.62139869107,
#    6511.668964247069,
#    6511.7165298030695,
#    6511.76409535907,
#    6511.811660915069,
#    6511.85922647107,
#    6511.90679202707,
#    6511.954357583069,
#    6512.00192313907,
# ...

# %%
wls, data = specs[4].fulldata

# %%
def calc_r_squared(fit, wls, data):
    # R^2 = 1 - SSline/SStotal
    wls, data = map(np.array, [wls, data])
    ss_line_data = data - fit(data)
    ss_line = sum(ss_line_data**2)
    avg = np.average(data)
    ss_tot = sum([(wl - avg)**2 for wl in wls])
    r_squared = 1-(ss_line/ss_tot)
    return r_squared

# %%
xd = np.array(range(50))
yd = xd ** 2
lfit = np.poly1d(np.polyfit(xd, yd, 1))
qfit = np.poly1d(np.polyfit(xd, yd, 2))

# %%
xd2 = range(50)
yd2 = [x**2 for x in xd2]
lfit2 = np.poly1d(np.polyfit(xd2, yd2, 1))
qfit2 = np.poly1d(np.polyfit(xd2, yd2, 2))

# %%
calc_r_squared(lfit, xd, yd)
# Out:
# -4402.6518877134276

# %%
calc_r_squared(lfit2, xd2, yd2)
# Out:
# -4402.6518877134276

# %%
calc_r_squared(qfit, xd, yd)
# Out:
# -6433792.6085657962

# %%
lfit
# Out:
# poly1d([  49., -392.])

# %%
plt.plot(xd, yd, 'o', xd, lfit(xd), '-r', xd, qfit(xd), '-g')
