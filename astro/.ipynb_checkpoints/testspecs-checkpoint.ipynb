# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 7)
import myfun as m
import myfun.astro as ast
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s = ast.rspec(filt='psi')
print s.obj_name
# Out:
# psi per

# %%
s.plot()

# %%
data = s.fulldata

# %%
ast.normalize_data(*data)

# %%
ast.normalize_spec(*data, tol=1)

# %%
wls, data = s.fulldata
fit = np.poly1d(np.polyfit(wls, data, 1))
ss_line_data = data - fit(data)
ss_line = sum(ss_line_data ** 2)
avg = np.average(data)
ss_tot = sum([(wl - avg)**2 for wl in wls]])
# Out:
#   File "<ipython-input-34-95e3c16bc713>", line 6
#     ss_tot = sum([(wl - avg)**2 for wl in wls]]
#                                               ^
# SyntaxError: invalid syntax

# %%
ss_line
# Out:
# 1309017.4
